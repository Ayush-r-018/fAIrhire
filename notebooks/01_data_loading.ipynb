# %%
# 1. Import Libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 100)

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
# 2. Load the Datasets
job_df = pd.read_csv("../data/raw/job_description_dataset.csv")
resume_df = pd.read_csv("../data/processed/resume_dataset_v3.csv")

print("Datasets loaded successfully.")
# Out:
# Datasets loaded successfully.

# %%
# 3. Check Dataset Shapes
print("Job Dataset Shape:", job_df.shape)
print("Resume Dataset Shape:", resume_df.shape)
# Out:
# Job Dataset Shape: (1068, 7)
# Resume Dataset Shape: (150000, 5)

# %%
# 4. View Column Names
print("Job Dataset Columns")
print(job_df.columns)

print("\nResume Dataset Columns")
print(resume_df.columns)
# Out:
# Job Dataset Columns
# Index(['JobID', 'Title', 'ExperienceLevel', 'YearsOfExperience', 'Skills',
#        'Responsibilities', 'Keywords'],
#       dtype='str')
#
# Resume Dataset Columns
# Index(['Role', 'Resume', 'Decision', 'Reason_for_decision', 'Job_Description'], dtype='str')

# %%
# 5. Display First Five Rows
print("Job Dataset")
display(job_df.head())

print("Resume Dataset")
display(resume_df.head())
# Out:
# Job Dataset
#        JobID           Title ExperienceLevel YearsOfExperience  \
# 0  NET-F-001  .NET Developer         Fresher               0-1
# 1  NET-F-002  .NET Developer         Fresher               0-1
# 2  NET-F-003  .NET Developer         Fresher               0-1
# 3  NET-F-004  .NET Developer         Fresher               0-1
# 4  NET-F-005  .NET Developer         Fresher               0-1
#
#                                                                                                 Skills  \
# 0  C#; VB.NET basics; .NET Framework; .NET Core fundamentals; ASP.NET; MVC; HTML; CSS; JavaScript b...
# 1  C#; .NET Framework basics; ASP.NET; Razor; HTML; CSS; JavaScript basics; SQL Server; Entity Fram...
# 2             C#; VB.NET basics; .NET Core; ASP.NET MVC; HTML; CSS; JavaScript basics; SQL Server; Git
# 3                       C#; .NET Framework; ASP.NET basics; SQL Server; HTML; CSS; LINQ; Visual Studio
# 4                  C#; ASP.NET; MVC; Entity Framework basics; SQL Server; HTML; CSS; JavaScript basics
#
#                                                                                       Responsibilities  \
# 0  Assist in coding and debugging applications; Learn and apply .NET Framework and Core fundamental...
# 1  Write simple C# programs under guidance; Support development of ASP.NET MVC applications; Implem...
# 2  Contribute to development of small modules; Assist in bug fixing and debugging; Learn and implem...
# 3  Support in software design documentation; Assist senior developers in testing; Create small UI c...
# 4  Learn to design and build ASP.NET applications; Assist in connecting apps to SQL Server; Work on...
#
#                                                                                  Keywords
# 0  .NET; C#; ASP.NET MVC; Entity Framework; SQL Server; LINQ; Visual Studio; Unit Testing
# 1                .NET; C#; ASP.NET MVC; Entity Framework; SQL Server; Razor; Unit Testing
# 2                                .NET; C#; ASP.NET MVC; SQL Server; Entity Framework; Git
# 3                                         .NET; C#; SQL Server; Entity Framework; ASP.NET
# 4                                     .NET; C#; ASP.NET MVC; Entity Framework; SQL Server
# Resume Dataset
#                            Role  \
# 0            Operations Manager
# 1           Full Stack Engineer
# 2   Customer Support Specialist
# 3   Customer Support Specialist
# 4  Business Development Manager
#
#                                                                                                 Resume  \
# 0  Operations Manager with 7 years of experience in FinTech. ['Asana' 'KPIs' 'Project Planning' 'Ri...
# 1  Software Engineer with 5 years of experience in Gaming. ['JavaScript' 'Unit Testing' 'Git' 'CI/C...
# 2  Sales Representative with 2 years of experience in Travel. ['Closing' 'CRM' 'Discovery Calls' 'P...
# 3  FP&A Analyst with 3 years of experience in Cybersecurity. ['Valuation' 'KPIs' 'Variance Analysis...
# 4  Project Manager with 2 years of experience in Cybersecurity. ['Jira' 'Timeline Management' 'Cros...
#
#   Decision                                 Reason_for_decision  \
# 0   select  Resume matches the required skills and experience.
# 1   select  Resume matches the required skills and experience.
# 2   reject        Resume lacks important skills or experience.
# 3   reject        Resume lacks important skills or experience.
# 4   reject        Resume lacks important skills or experience.
#
#                                                                                        Job_Description
# 0  We are hiring a Operations Manager to support teams in E-commerce. ['Relevant experience and abi...
# 1  We are hiring a Full Stack Engineer to support teams in Retail. ['Relevant experience and abilit...
# 2  We are hiring a Customer Support Specialist to support teams in FinTech. ['Relevant experience a...
# 3  We are hiring a Customer Support Specialist to support teams in Travel. ['Relevant experience an...
# 4  We are hiring a Business Development Manager to support teams in Travel. ['Relevant experience a...

# %%
# 6. Dataset Information
print("Job Dataset Information")
job_df.info()

print("\nResume Dataset Information")
resume_df.info()
# Out:
# Job Dataset Information
# <class 'pandas.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   JobID              1068 non-null   str
#  1   Title              1067 non-null   str
#  2   ExperienceLevel    1068 non-null   str
#  3   YearsOfExperience  1068 non-null   str
#  4   Skills             1068 non-null   str
#  5   Responsibilities   1068 non-null   str
#  6   Keywords           1068 non-null   str
# dtypes: str(7)
# memory usage: 646.4 KB
#
# Resume Dataset Information
# <class 'pandas.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 5 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Role                 150000 non-null  str
#  1   Resume               150000 non-null  str
#  2   Decision             150000 non-null  str
#  3   Reason_for_decision  150000 non-null  str
#  4   Job_Description      150000 non-null  str
# dtypes: str(5)
# memory usage: 108.9 MB

# %%
# 7. Missing Values
print("Missing Values in Job Dataset")
display(job_df.isnull().sum())

print("Missing Values in Resume Dataset")
display(resume_df.isnull().sum())
# Out:
# Missing Values in Job Dataset
# JobID                0
# Title                1
# ExperienceLevel      0
# YearsOfExperience    0
# Skills               0
# Responsibilities     0
# Keywords             0
# dtype: int64
# Missing Values in Resume Dataset
# Role                   0
# Resume                 0
# Decision               0
# Reason_for_decision    0
# Job_Description        0
# dtype: int64

# %%
# 8. Duplicate Records
print("Duplicate Job Records:", job_df.duplicated().sum())
print("Duplicate Resume Records:", resume_df.duplicated().sum())
# Out:
# Duplicate Job Records: 0
# Duplicate Resume Records: 1

# %%
# 9. Target Class Distribution
resume_df["Decision"].value_counts()
# Out:
# Decision
# select    75000
# reject    75000
# Name: count, dtype: int64

# %%
decision_distribution = (
    resume_df["Decision"]
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)

print("Decision Distribution (%)")
display(decision_distribution)
# Out:
# Decision Distribution (%)
# Decision
# select    50.0
# reject    50.0
# Name: proportion, dtype: float64

# %%
# 9.5. Visualize Target Class Distribution
plt.figure(figsize=(4,4))

ax = sns.countplot(
    data=resume_df,
    x="Decision",
    hue="Decision",
    palette="Set2",
    legend=False
)

# Add count labels
for container in ax.containers:
    ax.bar_label(container, fontsize=10)

plt.title("Distribution of Resume Screening Decisions", fontsize=10, fontweight="bold")
plt.xlabel("Decision Label", fontsize=8)
plt.ylabel("Number of Resumes", fontsize=8)

plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Summary and Observations
#
# ## Job Dataset
# - Total Records: **1,068**
# - Total Features: **7**
# - One missing value was found in the `Title` column.
# - All remaining columns are complete and stored as text.
#
# ## Resume Dataset
# - Total Records: **10,174**
# - Total Features: **5**
# - No missing values were found.
# - All columns are text-based, making the dataset suitable for NLP preprocessing.
#
# ## Target Variable
# - Target Column: **Decision**
# - Classes:
#   - Select: **5,060**
#   - Reject: **5,114**
#
# The target classes are nearly balanced (approximately 50:50), making the dataset suitable for supervised binary classification without additional class-balancing techniques.
#
# ## Conclusion
# The datasets have been successfully loaded and explored. The next step is to preprocess the textual data by cleaning, normalizing, and removing irrelevant information before feature engineering and model training.
